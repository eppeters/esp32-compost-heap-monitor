# %%
import serial

# %%
esp32 = serial.Serial('/dev/ttyS5', baudrate=115200, timeout=20)

# %%
print('receiving')
data = [int(i) for i in esp32.read(768)]
temps = [9/5 * i + 32 for i in data]
# Out:
# receiving

# %%
import colorcet as cc
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage

mlx_shape = (24,32)
mlx_interp_val = 10 # interpolate # on each dimension
mlx_interp_shape = (mlx_shape[0]*mlx_interp_val,
                    mlx_shape[1]*mlx_interp_val) # new shape

# setup the figure for plotting
plt.ion() # enables interactive plotting
fig,ax = plt.subplots(figsize=(12,7))
therm1 = ax.imshow(np.zeros(mlx_interp_shape), interpolation='none', vmin=0,vmax=110, cmap=cc.cm.rainbow) #start plot with zeros
cbar = fig.colorbar(therm1) # setup colorbar for temps
cbar.set_label('Temperature [$^{\circ}$F]',fontsize=14) # colorbar label
frame = np.zeros((24*32,)) # setup array for storing all 768 temperatures
t_array = []
data_array = (np.reshape(temps, mlx_shape)) # reshape to 24x32
data_array = (ndimage.zoom(data_array, mlx_interp_val))
therm1.set_data(np.fliplr(data_array)) # flip left to right
therm1.set_clim(vmin=np.min(data_array),vmax=np.max(data_array)) # set bounds
cbar.on_mappable_changed(therm1) # update colorbar range
plt.pause(0.001) # required
print('saving')
fig.savefig(f'mlx90640_test_fliplr.png',dpi=300,facecolor='#FCFCFC', bbox_inches='tight') # comment out to speed up
# Out:
# <ipython-input-22-58a644510c93>:23: MatplotlibDeprecationWarning:
# The on_mappable_changed function was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use update_normal instead.
#   cbar.on_mappable_changed(therm1) # update colorbar range
# saving

# %%
data
